# %%
import pandas as pd
df = pd.read_csv("robot.csv")
df.head()
# Out:
#   Robot_ID   Task_Type Component_ID Sensor_Type            Sensor_Data  \
# 0  RBT_001  Inspection      CMP_460       LIDAR  1 (obstacle detected)
# 1  RBT_002    Assembly      CMP_252     Thermal             85.3 (Â°C)
# 2  RBT_003  Inspection      CMP_248     Thermal       92% (visual fit)
# 3  RBT_004     Welding      CMP_433      Camera      98% (defect-free)
# 4  RBT_005    Assembly      CMP_992      Camera       92% (visual fit)
#
#    Processing_Time (s)  Accuracy (%) Environmental_Status  \
# 0                 67.0          90.4               Stable
# 1                 71.2          98.1               Stable
# 2                 49.2          95.3             Unstable
# 3                 74.5          90.2               Stable
# 4                 64.5          97.2             Unstable
#
#    Energy_Consumption (kWh) Human_Intervention_Needed Obstacle_Detected  \
# 0                       2.2                        No               Yes
# ...

# %%
average = df.Interaction_Count.mean()
total = df.Steps_Walked.sum()
max = df[df.columns[-1]].max()
min_energy_consumption = df[df.columns[-1]].min()
import matplotlib.pyplot as plt
co= df.Steps_Walked.corr(other=df[df.columns[-1]])
var = df.Learning_Sessions.var()
print("average robot conversation:",average)
print("total number of steps walked:",total)
print("maximum energy consumed:",max)
print("minimum energy consumed:",min)
print("correlation:",co)
print("variance:",var)
# Out:
# average robot conversation: 5.51
# total number of steps walked: 14379
# maximum energy consumed: 654
# minimum energy consumed: <built-in function min>
# correlation: 0.050369264265320374
# variance: 391.9422845691385

# %%
# Histogram for Objects Recognized
plt.hist(df.Objects_Recognized)
# Out:
# (array([15., 35., 75., 60., 60., 75., 45., 50., 40., 45.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Objects_Recognized'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Objects Recognized Daily')
plt.xlabel('Objects Recognized')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Scatter plot for Steps Walked vs. Energy Consumption
plt.figure(figsize=(8, 6))
plt.scatter(df['Steps_Walked'], df['Energy_Consumption (kWh)'], color='green')
plt.title('Steps Walked vs Energy Consumption')
plt.xlabel('Steps Walked')
plt.ylabel('Energy Consumption (kWh)')
plt.grid(True)
plt.show()

# %%
# Line plot for Learning Sessions over time (optional)
plt.figure(figsize=(8, 6))
plt.plot(df['Learning_Sessions'], color='purple', marker='o')
plt.title('Learning Sessions over Time')
plt.xlabel('Days')
plt.ylabel('Learning Sessions')
plt.grid(True)
plt.show()
