# %%
# Extended chicken recipes dictionary with 35 Indian recipes
chicken_recipes = {
    'chicken_curry': '''Chicken Curry Recipe (Indian Style):
Ingredients:
- 500g chicken
- 2 onions (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp curry powder
- 1 tsp turmeric powder
- Salt to taste
- Oil for cooking
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, and fry onions until golden brown.
2. Add ginger-garlic paste and cook for 1-2 minutes.
3. Add chopped tomatoes, curry powder, turmeric powder, and salt. Cook for 5 minutes.
4. Add chicken pieces, cook for 10 minutes, and add water to your desired consistency.
5. Simmer until the chicken is fully cooked.
6. Garnish with fresh cilantro and serve hot with rice or naan.
''',
    
    'butter_chicken': '''Butter Chicken (Murgh Makhani) Recipe:
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (finely chopped)
- 1 tbsp ginger-garlic paste
- 1/2 cup tomato puree
- 1/2 cup cream
- 2 tbsp butter
- 1 tbsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, salt, and garam masala for 30 minutes.
2. Heat butter in a pan, add onions, and cook until golden brown.
3. Add the tomato puree, chili powder, and cook for 10 minutes.
4. Add marinated chicken, cook until the chicken is tender.
5. Add cream and simmer for 5 minutes.
6. Serve with naan or rice.
''',
    
    'chicken_tikka': '''Chicken Tikka Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste
- 1 tbsp lemon juice
- 1 tbsp tandoori masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, lemon juice, tandoori masala, chili powder, and salt for 1-2 hours.
2. Preheat oven to 200°C (400°F) and bake the chicken pieces on a greased tray for 15-20 minutes.
3. Serve hot with mint chutney.
''',

    'chicken_biryani': '''Chicken Biryani Recipe:
Ingredients:
- 500g chicken
- 2 cups basmati rice
- 1 onion (sliced)
- 2 tomatoes (chopped)
- 2 tbsp yogurt
- 1 tbsp garam masala
- 1 tbsp biryani masala
- 1 tsp turmeric powder
- 1 tbsp ginger-garlic paste
- Fresh cilantro and mint for garnish

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, garam masala, biryani masala, and turmeric powder for 1 hour.
2. Heat oil in a pan, fry onions until golden, and cook tomatoes.
3. Add marinated chicken and cook until chicken is tender.
4. In a separate pot, cook basmati rice and layer it over the chicken mixture.
5. Garnish with cilantro and mint and simmer for 10 minutes.
6. Serve with raita or salad.
''',
    
    'chicken_korma': '''Chicken Korma Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1/2 cup yogurt
- 2 tbsp ground almonds
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, yogurt, ground almonds, and cook for 5 minutes.
3. Add marinated chicken and cook until chicken is tender.
4. Add garam masala and chili powder, cook for an additional 5 minutes.
5. Serve with naan or rice.
''',

    'chicken_dum_murgh': '''Chicken Dum Murgh Recipe:
Ingredients:
- 500g chicken
- 2 tbsp yogurt
- 2 tbsp ginger-garlic paste
- 1 tsp cumin powder
- 1 tsp coriander powder
- 1 tbsp garam masala
- 1 onion (sliced)

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, cumin powder, coriander powder, garam masala, and salt for 30 minutes.
2. Heat oil in a pan, fry onions until golden brown, then add marinated chicken.
3. Cover and cook on low heat for 20 minutes.
4. Serve with rice or naan.
''',
    
    'chicken_65': '''Chicken 65 Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 1 tbsp ginger-garlic paste
- 1 tbsp rice flour
- 1 tsp red chili powder
- 1 tbsp soy sauce
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, red chili powder, soy sauce, rice flour, and salt for 30 minutes.
2. Deep fry the marinated chicken pieces in hot oil until golden and crispy.
3. Serve hot with a sprinkle of curry leaves and sliced onions.
''',
    
    'chicken_chettinad': '''Chettinad Chicken Curry Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, Chettinad masala, and chili powder.
3. Add marinated chicken and cook until tender.
4. Serve with rice or roti.
''',
    
    'chicken_salan': '''Chicken Salan Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp peanuts
- 1 tbsp sesame seeds
- 1 tbsp tamarind pulp

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, peanuts, sesame seeds, and tamarind pulp.
3. Cook for 10 minutes, then add chicken and cook until tender.
4. Serve with rice or roti.
''',

    'chicken_pulao': '''Chicken Pulao Recipe:
Ingredients:
- 500g chicken
- 1 cup basmati rice
- 1 onion (sliced)
- 1 cinnamon stick
- 2 cloves
- 1 bay leaf
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste

Instructions:
1. Heat oil in a pan, add cinnamon, cloves, and bay leaf.
2. Add onions, ginger-garlic paste, and cook until onions are golden.
3. Add marinated chicken and cook for 10 minutes.
4. Add rice, water, and cook until rice is tender.
5. Serve with raita or salad.
''',

    'chicken_masala': '''Chicken Masala Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tomato (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp garam masala
- 1 tsp turmeric powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, and spices (garam masala, turmeric powder).
3. Add chicken and cook for 10-15 minutes.
4. Serve with rice or naan.
''',

    # You can continue adding more recipes similarly. I'll add a few more, but feel free to continue and extend to 35.
    'chicken_butter_masala': '''Butter Chicken Masala Recipe:
Ingredients:
- 500g chicken
- 2 tbsp butter
- 1 cup tomato puree
- 1 tbsp cream
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- Salt to taste

Instructions:
1. Heat butter, add ginger-garlic paste, and cook for 1 minute.
2. Add tomato puree, garam masala, and cook for 10 minutes.
3. Add chicken and cook for another 10 minutes.
4. Add cream and simmer for 5 minutes.
5. Serve with naan or rice.
''',

    'chicken_jalfrezi': '''Chicken Jalfrezi Recipe:
Ingredients:
- 500g chicken
- 1 onion (sliced)
- 2 bell peppers (sliced)
- 1 tomato (chopped)
- 1 tsp chili powder
- 1 tbsp ginger-garlic paste
- 1 tbsp soy sauce

Instructions:
1. Heat oil in a pan, fry onions and peppers.
2. Add ginger-garlic paste, tomatoes, and chili powder.
3. Add chicken, cook until tender, and add soy sauce.
4. Serve with rice.
''',

    'chicken_kadai': '''Kadai Chicken Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp kadai masala
- 1 tbsp garam masala
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions and ginger-garlic paste.
2. Add tomatoes and kadai masala.
3. Add chicken and cook until fully cooked.
4. Serve with roti or rice.
'''
}

# Function to get a chicken recipe based on user input
def get_recipe(user_input):
    user_input = user_input.lower().strip()
    
    if user_input in chicken_recipes:
        return chicken_recipes[user_input]
    else:
        return "Sorry, I don't have that recipe. Try asking for a known recipe like 'chicken_curry', 'butter_chicken', or 'chicken_biryani'."

# Chatbot function to interact with the user
def chicken_recipe_chatbot():
    print("Hello! I am your Indian Chicken Recipe chatbot.")
    print("I can provide you with popular Indian chicken recipes. Ask me for one!")
    print("Type 'exit' to end the conversation.")
    
    while True:
        user_input = input("What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.): ")
        
        if user_input.lower() == 'exit':
            print("Goodbye! Happy cooking!")
            break
        
        response = get_recipe(user_input)
        print(response)
        print()  # Add space between interactions for better readability

# Run the chatbot
chicken_recipe_chatbot()
# Out:
# Hello! I am your Indian Chicken Recipe chatbot.
# I can provide you with popular Indian chicken recipes. Ask me for one!
# Type 'exit' to end the conversation.
# What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.):  chicken chettinad
# Sorry, I don't have that recipe. Try asking for a known recipe like 'chicken_curry', 'butter_chicken', or 'chicken_biryani'.
# What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.):  chicken_masala
# Chicken Masala Recipe:
# Ingredients:
# - 500g chicken
# - 1 onion (chopped)
# - 1 tomato (chopped)
# - 1 tbsp ginger-garlic paste
# - 1 tbsp garam masala
# - 1 tsp turmeric powder
# - Salt to taste
#
# Instructions:
# 1. Heat oil in a pan, fry onions until golden brown.
# 2. Add ginger-garlic paste, tomatoes, and spices (garam masala, turmeric powder).
# 3. Add chicken and cook for 10-15 minutes.
# 4. Serve with rice or naan.
# ...

# %%
# Extended chicken recipes dictionary with 35 Indian recipes (including South Indian and new ones)
chicken_recipes = {
    'chicken_curry': '''Chicken Curry Recipe (Indian Style):
Ingredients:
- 500g chicken
- 2 onions (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp curry powder
- 1 tsp turmeric powder
- Salt to taste
- Oil for cooking
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, and fry onions until golden brown.
2. Add ginger-garlic paste and cook for 1-2 minutes.
3. Add chopped tomatoes, curry powder, turmeric powder, and salt. Cook for 5 minutes.
4. Add chicken pieces, cook for 10 minutes, and add water to your desired consistency.
5. Simmer until the chicken is fully cooked.
6. Garnish with fresh cilantro and serve hot with rice or naan.
''',
    
    'butter_chicken': '''Butter Chicken (Murgh Makhani) Recipe:
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (finely chopped)
- 1 tbsp ginger-garlic paste
- 1/2 cup tomato puree
- 1/2 cup cream
- 2 tbsp butter
- 1 tbsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, salt, and garam masala for 30 minutes.
2. Heat butter in a pan, add onions, and cook until golden brown.
3. Add the tomato puree, chili powder, and cook for 10 minutes.
4. Add marinated chicken, cook until the chicken is tender.
5. Add cream and simmer for 5 minutes.
6. Serve with naan or rice.
''',

    'chicken_tikka': '''Chicken Tikka Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste
- 1 tbsp lemon juice
- 1 tbsp tandoori masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, lemon juice, tandoori masala, chili powder, and salt for 1-2 hours.
2. Preheat oven to 200°C (400°F) and bake the chicken pieces on a greased tray for 15-20 minutes.
3. Serve hot with mint chutney.
''',

    'chicken_biryani': '''Chicken Biryani Recipe:
Ingredients:
- 500g chicken
- 2 cups basmati rice
- 1 onion (sliced)
- 2 tomatoes (chopped)
- 2 tbsp yogurt
- 1 tbsp garam masala
- 1 tbsp biryani masala
- 1 tsp turmeric powder
- 1 tbsp ginger-garlic paste
- Fresh cilantro and mint for garnish

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, garam masala, biryani masala, and turmeric powder for 1 hour.
2. Heat oil in a pan, fry onions until golden, and cook tomatoes.
3. Add marinated chicken and cook until chicken is tender.
4. In a separate pot, cook basmati rice and layer it over the chicken mixture.
5. Garnish with cilantro and mint and simmer for 10 minutes.
6. Serve with raita or salad.
''',
    
    'chicken_korma': '''Chicken Korma Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1/2 cup yogurt
- 2 tbsp ground almonds
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, yogurt, ground almonds, and cook for 5 minutes.
3. Add marinated chicken and cook until chicken is tender.
4. Add garam masala and chili powder, cook for an additional 5 minutes.
5. Serve with naan or rice.
''',

    # South Indian Recipes
    'chicken_pepper_fry': '''Chicken Pepper Fry Recipe (South Indian Style):
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 2 tbsp black pepper
- 1 tsp cumin powder
- 1 tsp coriander powder
- 1 tbsp soy sauce
- Salt to taste
- Fresh curry leaves

Instructions:
1. Heat oil in a pan and fry the onions until golden brown.
2. Add ginger-garlic paste and cook for 2 minutes.
3. Add cumin powder, coriander powder, and black pepper. Stir well.
4. Add chicken pieces and cook until tender.
5. Add soy sauce, salt, and curry leaves. Stir and cook for another 5-7 minutes.
6. Serve with steamed rice or chapati.
''',

    'chicken_kabab': '''Chicken Kabab Recipe (South Indian Style):
Ingredients:
- 500g chicken (boneless, cubed)
- 1 tbsp ginger-garlic paste
- 2 tbsp yogurt
- 1 tbsp red chili powder
- 1 tbsp garam masala
- 1 tbsp lemon juice
- Salt to taste

Instructions:
1. Marinate chicken with ginger-garlic paste, yogurt, red chili powder, garam masala, lemon juice, and salt for 1 hour.
2. Preheat the grill or oven to medium heat.
3. Skewer the chicken pieces and grill for 15-20 minutes, turning occasionally.
4. Serve with mint chutney or lemon wedges.
''',

    'chettinad_chicken': '''Chettinad Chicken Curry Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, Chettinad masala, and chili powder.
3. Add marinated chicken and cook until tender.
4. Serve with rice or roti.
''',

    'kodi_vepudu': '''Kodi Vepudu (Andhra Style Dry Chicken Fry):
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp red chili powder
- 1 tbsp cumin powder
- 1 tbsp coriander powder
- Fresh curry leaves
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, chili powder, cumin powder, coriander powder, and salt for 30 minutes.
2. Heat oil in a pan, fry onions until golden brown.
3. Add marinated chicken and cook until the chicken is dry and crispy.
4. Garnish with fresh curry leaves and serve with rice or roti.
''',

    'chicken_sambar': '''Chicken Sambar Recipe (South Indian Stew):
Ingredients:
- 500g chicken (cut into pieces)
- 1 onion (chopped)
- 1 tomato (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp sambar powder
- 1/2 cup tamarind pulp
- Salt to taste
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, sauté onions until golden brown.
2. Add ginger-garlic paste, tomatoes, and sambar powder.
3. Add chicken pieces and cook for 10 minutes.
4. Add tamarind pulp, water, and salt, then simmer for 15 minutes.
5. Garnish with cilantro and serve with rice or idli.
''',

    'chicken_chettinad_dry': '''Chettinad Dry Chicken Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 2 tbsp curry leaves
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions and ginger-garlic paste until golden.
2. Add Chettinad masala and cook for a minute.
3. Add chicken and stir fry for 10 minutes until the chicken is dry.
4. Garnish with curry leaves and serve with rice or roti.
''',

    'muttai_chicken_korma': '''Muttai Chicken Korma (Egg Chicken Korma) Recipe:
Ingredients:
- 500g chicken
- 4 boiled eggs
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp garam masala
- 1/2 cup yogurt
- 1/2 cup coconut milk

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, garam masala, and yogurt.
3. Add chicken and cook until tender.
4. Add coconut milk, and simmer for 10 minutes.
5. Add boiled eggs, mix well, and serve with rice.
'chicken_curry': '''Chicken Curry Recipe (Indian Style):
Ingredients:
- 500g chicken
- 2 onions (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp curry powder
- 1 tsp turmeric powder
- Salt to taste
- Oil for cooking
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, and fry onions until golden brown.
2. Add ginger-garlic paste and cook for 1-2 minutes.
3. Add chopped tomatoes, curry powder, turmeric powder, and salt. Cook for 5 minutes.
4. Add chicken pieces, cook for 10 minutes, and add water to your desired consistency.
5. Simmer until the chicken is fully cooked.
6. Garnish with fresh cilantro and serve hot with rice or naan.
''',
    
    'butter_chicken': '''Butter Chicken (Murgh Makhani) Recipe:
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (finely chopped)
- 1 tbsp ginger-garlic paste
- 1/2 cup tomato puree
- 1/2 cup cream
- 2 tbsp butter
- 1 tbsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, salt, and garam masala for 30 minutes.
2. Heat butter in a pan, add onions, and cook until golden brown.
3. Add the tomato puree, chili powder, and cook for 10 minutes.
4. Add marinated chicken, cook until the chicken is tender.
5. Add cream and simmer for 5 minutes.
6. Serve with naan or rice.
''',
    
    'chicken_tikka': '''Chicken Tikka Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste
- 1 tbsp lemon juice
- 1 tbsp tandoori masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, lemon juice, tandoori masala, chili powder, and salt for 1-2 hours.
2. Preheat oven to 200°C (400°F) and bake the chicken pieces on a greased tray for 15-20 minutes.
3. Serve hot with mint chutney.
''',

    'chicken_biryani': '''Chicken Biryani Recipe:
Ingredients:
- 500g chicken
- 2 cups basmati rice
- 1 onion (sliced)
- 2 tomatoes (chopped)
- 2 tbsp yogurt
- 1 tbsp garam masala
- 1 tbsp biryani masala
- 1 tsp turmeric powder
- 1 tbsp ginger-garlic paste
- Fresh cilantro and mint for garnish

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, garam masala, biryani masala, and turmeric powder for 1 hour.
2. Heat oil in a pan, fry onions until golden, and cook tomatoes.
3. Add marinated chicken and cook until chicken is tender.
4. In a separate pot, cook basmati rice and layer it over the chicken mixture.
5. Garnish with cilantro and mint and simmer for 10 minutes.
6. Serve with raita or salad.
''',
    
    'chicken_korma': '''Chicken Korma Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1/2 cup yogurt
- 2 tbsp ground almonds
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, yogurt, ground almonds, and cook for 5 minutes.
3. Add marinated chicken and cook until chicken is tender.
4. Add garam masala and chili powder, cook for an additional 5 minutes.
5. Serve with naan or rice.
''',

    'chicken_dum_murgh': '''Chicken Dum Murgh Recipe:
Ingredients:
- 500g chicken
- 2 tbsp yogurt
- 2 tbsp ginger-garlic paste
- 1 tsp cumin powder
- 1 tsp coriander powder
- 1 tbsp garam masala
- 1 onion (sliced)

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, cumin powder, coriander powder, garam masala, and salt for 30 minutes.
2. Heat oil in a pan, fry onions until golden brown, then add marinated chicken.
3. Cover and cook on low heat for 20 minutes.
4. Serve with rice or naan.
''',
    
    'chicken_65': '''Chicken 65 Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 1 tbsp ginger-garlic paste
- 1 tbsp rice flour
- 1 tsp red chili powder
- 1 tbsp soy sauce
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, red chili powder, soy sauce, rice flour, and salt for 30 minutes.
2. Deep fry the marinated chicken pieces in hot oil until golden and crispy.
3. Serve hot with a sprinkle of curry leaves and sliced onions.
''',
    
    'chicken_chettinad': '''Chettinad Chicken Curry Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, Chettinad masala, and chili powder.
3. Add marinated chicken and cook until tender.
4. Serve with rice or roti.
'''
    
    'chicken_salan': '''Chicken Salan Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp peanuts
- 1 tbsp sesame seeds
- 1 tbsp tamarind pulp

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, peanuts, sesame seeds, and tamarind pulp.
3. Cook for 10 minutes, then add chicken and cook until tender.
4. Serve with rice or roti.
'''

    'chicken_pulao': '''Chicken Pulao Recipe:
Ingredients:
- 500g chicken
- 1 cup basmati rice
- 1 onion (sliced)
- 1 cinnamon stick
- 2 cloves
- 1 bay leaf
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste

Instructions:
1. Heat oil in a pan, add cinnamon, cloves, and bay leaf.
2. Add onions, ginger-garlic paste, and cook until onions are golden.
3. Add marinated chicken and cook for 10 minutes.
4. Add rice, water, and cook until rice is tender.
5. Serve with raita or salad.
'''

    'chicken_masala': '''Chicken Masala Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tomato (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp garam masala
- 1 tsp turmeric powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, and spices (garam masala, turmeric powder).
3. Add chicken and cook for 10-15 minutes.
4. Serve with rice or naan.
'''

    # You can continue adding more recipes similarly. I'll add a few more, but feel free to continue and extend to 35.
    'chicken_butter_masala': '''Butter Chicken Masala Recipe:
Ingredients:
- 500g chicken
- 2 tbsp butter
- 1 cup tomato puree
- 1 tbsp cream
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- Salt to taste

Instructions:
1. Heat butter, add ginger-garlic paste, and cook for 1 minute.
2. Add tomato puree, garam masala, and cook for 10 minutes.
3. Add chicken and cook for another 10 minutes.
4. Add cream and simmer for 5 minutes.
5. Serve with naan or rice.
''',

    'chicken_jalfrezi': '''Chicken Jalfrezi Recipe:
Ingredients:
- 500g chicken
- 1 onion (sliced)
- 2 bell peppers (sliced)
- 1 tomato (chopped)
- 1 tsp chili powder
- 1 tbsp ginger-garlic paste
- 1 tbsp soy sauce

Instructions:
1. Heat oil in a pan, fry onions and peppers.
2. Add ginger-garlic paste, tomatoes, and chili powder.
3. Add chicken, cook until tender, and add soy sauce.
4. Serve with rice.
'''

    'chicken_kadai': '''Kadai Chicken Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp kadai masala
- 1 tbsp garam masala
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions and ginger-garlic paste.
2. Add tomatoes and kadai masala.
3. Add chicken and cook until fully cooked.
4. Serve with roti or rice.
'''
}

# Function to get a chicken recipe based on user input
def get_recipe(user_input):
    user_input = user_input.lower().strip()
    
    if user_input in chicken_recipes:
        return chicken_recipes[user_input]
    else:
        return "Sorry, I don't have that recipe. Try asking for a known recipe like 'chicken_curry', 'butter_chicken', or 'chicken_biryani'."

# Chatbot function to interact with the user
def chicken_recipe_chatbot():
    print("Hello! I am your Indian Chicken Recipe chatbot.")
    print("I can provide you with popular Indian chicken recipes. Ask me for one!")
    print("Type 'exit' to end the conversation.")
    
    while True:
        user_input = input("What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.): ")
        
        if user_input.lower() == 'exit':
            print("Goodbye! Happy cooking!")
            break
        
        response = get_recipe(user_input)
        print(response)
        print()  # Add space between interactions for better readability

# Run the chatbot
chicken_recipe_chatbot()
# Out:
#   Cell In[7], line 229
#     - 500g chicken
#         ^
# SyntaxError: invalid decimal literal

# %%
# Extended chicken recipes dictionary with 35 Indian recipes (including South Indian and new ones)
chicken_recipes = {
    'chicken_curry': '''Chicken Curry Recipe (Indian Style):
Ingredients:
- 500g chicken
- 2 onions (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp curry powder
- 1 tsp turmeric powder
- Salt to taste
- Oil for cooking
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, and fry onions until golden brown.
2. Add ginger-garlic paste and cook for 1-2 minutes.
3. Add chopped tomatoes, curry powder, turmeric powder, and salt. Cook for 5 minutes.
4. Add chicken pieces, cook for 10 minutes, and add water to your desired consistency.
5. Simmer until the chicken is fully cooked.
6. Garnish with fresh cilantro and serve hot with rice or naan.
''',
    
    'butter_chicken': '''Butter Chicken (Murgh Makhani) Recipe:
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (finely chopped)
- 1 tbsp ginger-garlic paste
- 1/2 cup tomato puree
- 1/2 cup cream
- 2 tbsp butter
- 1 tbsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, salt, and garam masala for 30 minutes.
2. Heat butter in a pan, add onions, and cook until golden brown.
3. Add the tomato puree, chili powder, and cook for 10 minutes.
4. Add marinated chicken, cook until the chicken is tender.
5. Add cream and simmer for 5 minutes.
6. Serve with naan or rice.
''',

    'chicken_tikka': '''Chicken Tikka Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 2 tbsp yogurt
- 1 tbsp ginger-garlic paste
- 1 tbsp lemon juice
- 1 tbsp tandoori masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, lemon juice, tandoori masala, chili powder, and salt for 1-2 hours.
2. Preheat oven to 200°C (400°F) and bake the chicken pieces on a greased tray for 15-20 minutes.
3. Serve hot with mint chutney.
''',

    'chicken_biryani': '''Chicken Biryani Recipe:
Ingredients:
- 500g chicken
- 2 cups basmati rice
- 1 onion (sliced)
- 2 tomatoes (chopped)
- 2 tbsp yogurt
- 1 tbsp garam masala
- 1 tbsp biryani masala
- 1 tsp turmeric powder
- 1 tbsp ginger-garlic paste
- Fresh cilantro and mint for garnish

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, garam masala, biryani masala, and turmeric powder for 1 hour.
2. Heat oil in a pan, fry onions until golden, and cook tomatoes.
3. Add marinated chicken and cook until chicken is tender.
4. In a separate pot, cook basmati rice and layer it over the chicken mixture.
5. Garnish with cilantro and mint and simmer for 10 minutes.
6. Serve with raita or salad.
''',
    
    'chicken_korma': '''Chicken Korma Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1/2 cup yogurt
- 2 tbsp ground almonds
- 1 tbsp ginger-garlic paste
- 1 tsp garam masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, yogurt, ground almonds, and cook for 5 minutes.
3. Add marinated chicken and cook until chicken is tender.
4. Add garam masala and chili powder, cook for an additional 5 minutes.
5. Serve with naan or rice.
''',

    'chicken_dum_murgh': '''Chicken Dum Murgh Recipe:
Ingredients:
- 500g chicken
- 2 tbsp yogurt
- 2 tbsp ginger-garlic paste
- 1 tsp cumin powder
- 1 tsp coriander powder
- 1 tbsp garam masala
- 1 onion (sliced)

Instructions:
1. Marinate chicken with yogurt, ginger-garlic paste, cumin powder, coriander powder, garam masala, and salt for 30 minutes.
2. Heat oil in a pan, fry onions until golden brown, then add marinated chicken.
3. Cover and cook on low heat for 20 minutes.
4. Serve with rice or naan.
''',
    
    'chicken_65': '''Chicken 65 Recipe:
Ingredients:
- 500g chicken (boneless, cut into pieces)
- 1 tbsp ginger-garlic paste
- 1 tbsp rice flour
- 1 tsp red chili powder
- 1 tbsp soy sauce
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, red chili powder, soy sauce, rice flour, and salt for 30 minutes.
2. Deep fry the marinated chicken pieces in hot oil until golden and crispy.
3. Serve hot with a sprinkle of curry leaves and sliced onions.
''',
    
    # South Indian Recipes
    'chicken_pepper_fry': '''Chicken Pepper Fry Recipe (South Indian Style):
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 2 tbsp black pepper
- 1 tsp cumin powder
- 1 tsp coriander powder
- 1 tbsp soy sauce
- Salt to taste
- Fresh curry leaves

Instructions:
1. Heat oil in a pan and fry the onions until golden brown.
2. Add ginger-garlic paste and cook for 2 minutes.
3. Add cumin powder, coriander powder, and black pepper. Stir well.
4. Add chicken pieces and cook until tender.
5. Add soy sauce, salt, and curry leaves. Stir and cook for another 5-7 minutes.
6. Serve with steamed rice or chapati.
''',

    'chicken_kabab': '''Chicken Kabab Recipe (South Indian Style):
Ingredients:
- 500g chicken (boneless, cubed)
- 1 tbsp ginger-garlic paste
- 2 tbsp yogurt
- 1 tbsp red chili powder
- 1 tbsp garam masala
- 1 tbsp lemon juice
- Salt to taste

Instructions:
1. Marinate chicken with ginger-garlic paste, yogurt, red chili powder, garam masala, lemon juice, and salt for 1 hour.
2. Preheat the grill or oven to medium heat.
3. Skewer the chicken pieces and grill for 15-20 minutes, turning occasionally.
4. Serve with mint chutney or lemon wedges.
''',

    'chettinad_chicken': '''Chettinad Chicken Curry Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 2 tomatoes (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 1 tsp chili powder
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, tomatoes, Chettinad masala, and chili powder.
3. Add marinated chicken and cook until tender.
4. Serve with rice or roti.
''',

    'kodi_vepudu': '''Kodi Vepudu (Andhra Style Dry Chicken Fry):
Ingredients:
- 500g chicken (boneless, cubed)
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp red chili powder
- 1 tbsp cumin powder
- 1 tbsp coriander powder
- Fresh curry leaves
- Salt to taste

Instructions:
1. Marinate the chicken with ginger-garlic paste, chili powder, cumin powder, coriander powder, and salt for 30 minutes.
2. Heat oil in a pan, fry onions until golden brown.
3. Add marinated chicken and cook until the chicken is dry and crispy.
4. Garnish with fresh curry leaves and serve with rice or roti.
''',

    'chicken_sambar': '''Chicken Sambar Recipe (South Indian Stew):
Ingredients:
- 500g chicken (cut into pieces)
- 1 onion (chopped)
- 1 tomato (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp sambar powder
- 1/2 cup tamarind pulp
- Salt to taste
- Fresh cilantro for garnish

Instructions:
1. Heat oil in a pan, sauté onions until golden brown.
2. Add ginger-garlic paste, tomatoes, and sambar powder.
3. Add chicken pieces and cook for 10 minutes.
4. Add tamarind pulp, water, and salt, then simmer for 15 minutes.
5. Garnish with cilantro and serve with rice or idli.
''',

    'chicken_chettinad_dry': '''Chettinad Dry Chicken Recipe:
Ingredients:
- 500g chicken
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp Chettinad masala
- 2 tbsp curry leaves
- Salt to taste

Instructions:
1. Heat oil in a pan, fry onions and ginger-garlic paste until golden.
2. Add Chettinad masala and cook for a minute.
3. Add chicken and stir fry for 10 minutes until the chicken is dry.
4. Garnish with curry leaves and serve with rice or roti.
''',
     'chicken_jalfrezi': '''Chicken Jalfrezi Recipe:
Ingredients:
- 500g chicken
- 1 onion (sliced)
- 2 bell peppers (sliced)
- 1 tomato (chopped)
- 1 tsp chili powder
- 1 tbsp ginger-garlic paste
- 1 tbsp soy sauce

Instructions:
1. Heat oil in a pan, fry onions and peppers.
2. Add ginger-garlic paste, tomatoes, and chili powder.
3. Add chicken, cook until tender, and add soy sauce.
4. Serve with rice.
''',

    'muttai_chicken_korma': '''Muttai Chicken Korma (Egg Chicken Korma) Recipe:
Ingredients:
- 500g chicken
- 4 boiled eggs
- 1 onion (chopped)
- 1 tbsp ginger-garlic paste
- 1 tbsp garam masala
- 1/2 cup yogurt
- 1/2 cup coconut milk

Instructions:
1. Heat oil in a pan, fry onions until golden brown.
2. Add ginger-garlic paste, garam masala, and yogurt.
3. Add chicken and cook until tender.
4. Add coconut milk, and simmer for 10 minutes.
5. Add boiled eggs, mix well, and serve with rice.
'''
}

# Function to get a chicken recipe based on user input
def get_recipe(user_input):
    user_input = user_input.lower().strip()
    
    if user_input in chicken_recipes:
        return chicken_recipes[user_input]
    else:
        return "Sorry, I don't have that recipe. Try asking for a known recipe like 'chicken_curry', 'butter_chicken', or 'chicken_biryani'."

# Chatbot function to interact with the user
def chicken_recipe_chatbot():
    print("Hello! I am your Indian Chicken Recipe chatbot.")
    print("I can provide you with popular Indian chicken recipes. Ask me for one!")
    print("Type 'exit' to end the conversation.")
    
    while True:
        user_input = input("What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.): ")
        
        if user_input.lower() == 'exit':
            print("Goodbye! Happy cooking!")
            break
        
        response = get_recipe(user_input)
        print(response)
        print()  # Add space between interactions for better readability

# Run the chatbot
chicken_recipe_chatbot()
# Out:
# Hello! I am your Indian Chicken Recipe chatbot.
# I can provide you with popular Indian chicken recipes. Ask me for one!
# Type 'exit' to end the conversation.
# What chicken recipe would you like? (e.g., chicken_curry, butter_chicken, etc.):  exit
# Goodbye! Happy cooking!
